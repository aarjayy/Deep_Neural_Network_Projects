# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'CS231n/Project/a4'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/CS231n/Project/a4

# %%
pip install -r gpu_requirements.txt
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: tqdm==4.29.1 in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 3)) (4.29.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 4)) (0.1.96)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r gpu_requirements.txt (line 6)) (1.9.0+cu102)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->-r gpu_requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->-r gpu_requirements.txt (line 5)) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->-r gpu_requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu->-r gpu_requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->-r gpu_requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->-r gpu_requirements.txt (line 5)) (2019.12.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r gpu_requirements.txt (line 6)) (3.7.4.3)

# %%
# %%shell
# sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 207.12, avg. ppl 3171.48 cum. examples 320, speed 3286.59 words/sec, time elapsed 2.50 sec
# epoch 1, iter 20, avg. loss 177.04, avg. ppl 742.99 cum. examples 640, speed 3530.27 words/sec, time elapsed 4.93 sec
# epoch 1, iter 30, avg. loss 164.91, avg. ppl 542.74 cum. examples 960, speed 3330.05 words/sec, time elapsed 7.45 sec
# epoch 1, iter 40, avg. loss 170.69, avg. ppl 477.00 cum. examples 1280, speed 3275.64 words/sec, time elapsed 10.15 sec
# epoch 1, iter 50, avg. loss 162.16, avg. ppl 371.79 cum. examples 1600, speed 3674.23 words/sec, time elapsed 12.54 sec
# epoch 1, iter 60, avg. loss 153.64, avg. ppl 346.33 cum. examples 1920, speed 3627.35 words/sec, time elapsed 14.85 sec
# epoch 1, iter 70, avg. loss 153.04, avg. ppl 296.66 cum. examples 2240, speed 3324.71 words/sec, time elapsed 17.44 sec
# epoch 1, iter 80, avg. loss 151.02, avg. ppl 300.19 cum. examples 2560, speed 3310.49 words/sec, time elapsed 20.00 sec
# epoch 1, iter 90, avg. loss 143.93, avg. ppl 265.12 cum. examples 2880, speed 3198.88 words/sec, time elapsed 22.58 sec
# epoch 1, iter 100, avg. loss 142.70, avg. ppl 221.87 cum. examples 3200, speed 3557.09 words/sec, time elapsed 24.96 sec
# epoch 1, iter 110, avg. loss 139.75, avg. ppl 223.91 cum. examples 3520, speed 3434.17 words/sec, time elapsed 27.36 sec
# epoch 1, iter 120, avg. loss 129.62, avg. ppl 194.40 cum. examples 3840, speed 3615.72 words/sec, time elapsed 29.54 sec
# epoch 1, iter 130, avg. loss 136.66, avg. ppl 183.49 cum. examples 4160, speed 3678.03 words/sec, time elapsed 31.82 sec
# epoch 1, iter 140, avg. loss 132.88, avg. ppl 180.93 cum. examples 4480, speed 3488.49 words/sec, time elapsed 34.17 sec
# epoch 1, iter 150, avg. loss 134.64, avg. ppl 171.57 cum. examples 4800, speed 3758.39 words/sec, time elapsed 36.39 sec
# epoch 1, iter 160, avg. loss 129.54, avg. ppl 158.08 cum. examples 5120, speed 3484.46 words/sec, time elapsed 38.74 sec
# epoch 1, iter 170, avg. loss 132.23, avg. ppl 162.89 cum. examples 5440, speed 3071.63 words/sec, time elapsed 41.45 sec
# epoch 1, iter 180, avg. loss 137.72, avg. ppl 149.70 cum. examples 5760, speed 3527.63 words/sec, time elapsed 43.94 sec
# epoch 1, iter 190, avg. loss 136.11, avg. ppl 160.77 cum. examples 6080, speed 3088.39 words/sec, time elapsed 46.72 sec
# epoch 1, iter 200, avg. loss 128.13, avg. ppl 138.04 cum. examples 6400, speed 2994.69 words/sec, time elapsed 49.50 sec
# epoch 1, iter 200, cum. loss 148.18, cum. ppl 280.42 cum. examples 6400
# begin validation ...
# validation: iter 200, dev. ppl 148.146585
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 210, avg. loss 123.08, avg. ppl 148.83 cum. examples 320, speed 907.49 words/sec, time elapsed 58.17 sec
# epoch 1, iter 220, avg. loss 132.77, avg. ppl 135.54 cum. examples 640, speed 3505.59 words/sec, time elapsed 60.64 sec
# epoch 1, iter 230, avg. loss 122.52, avg. ppl 117.46 cum. examples 960, speed 3592.11 words/sec, time elapsed 62.93 sec
# epoch 1, iter 240, avg. loss 126.62, avg. ppl 115.60 cum. examples 1280, speed 3297.03 words/sec, time elapsed 65.52 sec
# epoch 1, iter 250, avg. loss 127.55, avg. ppl 117.38 cum. examples 1600, speed 3489.38 words/sec, time elapsed 67.97 sec
# epoch 1, iter 260, avg. loss 126.56, avg. ppl 102.16 cum. examples 1920, speed 3576.95 words/sec, time elapsed 70.42 sec
# epoch 1, iter 270, avg. loss 114.81, avg. ppl 103.77 cum. examples 2240, speed 3565.91 words/sec, time elapsed 72.64 sec
# epoch 1, iter 280, avg. loss 121.32, avg. ppl 106.10 cum. examples 2560, speed 3400.76 words/sec, time elapsed 75.09 sec
# epoch 1, iter 290, avg. loss 129.94, avg. ppl 124.69 cum. examples 2880, speed 3210.93 words/sec, time elapsed 77.77 sec
# epoch 1, iter 300, avg. loss 121.41, avg. ppl 103.42 cum. examples 3200, speed 3511.41 words/sec, time elapsed 80.16 sec
# epoch 1, iter 310, avg. loss 121.57, avg. ppl 96.72 cum. examples 3520, speed 3540.27 words/sec, time elapsed 82.56 sec
# epoch 1, iter 320, avg. loss 119.23, avg. ppl 95.13 cum. examples 3840, speed 3201.43 words/sec, time elapsed 85.18 sec
# epoch 1, iter 330, avg. loss 122.39, avg. ppl 101.88 cum. examples 4160, speed 3612.81 words/sec, time elapsed 87.52 sec
# epoch 1, iter 340, avg. loss 105.46, avg. ppl 86.81 cum. examples 4480, speed 3392.05 words/sec, time elapsed 89.75 sec
# epoch 1, iter 350, avg. loss 113.84, avg. ppl 89.87 cum. examples 4800, speed 3647.96 words/sec, time elapsed 91.97 sec
# epoch 1, iter 360, avg. loss 113.66, avg. ppl 86.34 cum. examples 5120, speed 3100.04 words/sec, time elapsed 94.60 sec
# epoch 1, iter 370, avg. loss 113.80, avg. ppl 89.45 cum. examples 5440, speed 3313.05 words/sec, time elapsed 97.05 sec
# epoch 1, iter 380, avg. loss 115.05, avg. ppl 95.60 cum. examples 5760, speed 3278.07 words/sec, time elapsed 99.51 sec
# epoch 1, iter 390, avg. loss 117.58, avg. ppl 81.73 cum. examples 6080, speed 3139.92 words/sec, time elapsed 102.23 sec
# epoch 1, iter 400, avg. loss 119.26, avg. ppl 83.41 cum. examples 6400, speed 3218.96 words/sec, time elapsed 104.91 sec
# epoch 1, iter 400, cum. loss 120.42, cum. ppl 102.81 cum. examples 6400
# begin validation ...
# validation: iter 400, dev. ppl 90.507677
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 410, avg. loss 110.18, avg. ppl 72.31 cum. examples 320, speed 1002.61 words/sec, time elapsed 113.13 sec
# epoch 1, iter 420, avg. loss 112.58, avg. ppl 69.29 cum. examples 640, speed 3661.57 words/sec, time elapsed 115.45 sec
# epoch 1, iter 430, avg. loss 115.23, avg. ppl 87.12 cum. examples 960, speed 3475.21 words/sec, time elapsed 117.82 sec
# epoch 1, iter 440, avg. loss 113.04, avg. ppl 76.41 cum. examples 1280, speed 3157.94 words/sec, time elapsed 120.47 sec
# epoch 1, iter 450, avg. loss 107.75, avg. ppl 71.83 cum. examples 1600, speed 3015.72 words/sec, time elapsed 123.14 sec
# epoch 1, iter 460, avg. loss 115.09, avg. ppl 81.11 cum. examples 1920, speed 3127.22 words/sec, time elapsed 125.82 sec
# epoch 2, iter 470, avg. loss 110.78, avg. ppl 61.97 cum. examples 2215, speed 3105.48 words/sec, time elapsed 128.37 sec
# epoch 2, iter 480, avg. loss 104.57, avg. ppl 51.81 cum. examples 2535, speed 3378.17 words/sec, time elapsed 130.88 sec
# epoch 2, iter 490, avg. loss 103.46, avg. ppl 55.04 cum. examples 2855, speed 3148.26 words/sec, time elapsed 133.50 sec
# epoch 2, iter 500, avg. loss 100.04, avg. ppl 52.82 cum. examples 3175, speed 3028.67 words/sec, time elapsed 136.17 sec
# epoch 2, iter 510, avg. loss 101.96, avg. ppl 50.88 cum. examples 3495, speed 2979.13 words/sec, time elapsed 138.95 sec
# epoch 2, iter 520, avg. loss 99.65, avg. ppl 53.03 cum. examples 3815, speed 3356.69 words/sec, time elapsed 141.35 sec
# epoch 2, iter 530, avg. loss 104.25, avg. ppl 48.34 cum. examples 4135, speed 3145.56 words/sec, time elapsed 144.08 sec
# epoch 2, iter 540, avg. loss 103.24, avg. ppl 50.87 cum. examples 4455, speed 3159.38 words/sec, time elapsed 146.74 sec
# epoch 2, iter 550, avg. loss 101.23, avg. ppl 46.78 cum. examples 4775, speed 3141.34 words/sec, time elapsed 149.42 sec
# epoch 2, iter 560, avg. loss 104.35, avg. ppl 50.42 cum. examples 5095, speed 3485.15 words/sec, time elapsed 151.87 sec
# epoch 2, iter 570, avg. loss 104.53, avg. ppl 55.34 cum. examples 5415, speed 3097.38 words/sec, time elapsed 154.56 sec
# epoch 2, iter 580, avg. loss 100.56, avg. ppl 52.00 cum. examples 5735, speed 3340.22 words/sec, time elapsed 157.00 sec
# epoch 2, iter 590, avg. loss 105.91, avg. ppl 44.55 cum. examples 6055, speed 3261.07 words/sec, time elapsed 159.73 sec
# epoch 2, iter 600, avg. loss 104.52, avg. ppl 47.87 cum. examples 6375, speed 3487.41 words/sec, time elapsed 162.21 sec
# epoch 2, iter 600, cum. loss 106.13, cum. ppl 57.70 cum. examples 6375
# begin validation ...
# validation: iter 600, dev. ppl 67.571336
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 2, iter 610, avg. loss 104.58, avg. ppl 51.39 cum. examples 320, speed 1036.46 words/sec, time elapsed 170.41 sec
# epoch 2, iter 620, avg. loss 104.50, avg. ppl 45.56 cum. examples 640, speed 3558.78 words/sec, time elapsed 172.87 sec
# epoch 2, iter 630, avg. loss 91.33, avg. ppl 40.78 cum. examples 960, speed 3309.47 words/sec, time elapsed 175.25 sec
# epoch 2, iter 640, avg. loss 112.61, avg. ppl 54.06 cum. examples 1280, speed 3179.65 words/sec, time elapsed 178.09 sec
# epoch 2, iter 650, avg. loss 95.20, avg. ppl 46.56 cum. examples 1600, speed 3085.99 words/sec, time elapsed 180.66 sec
# epoch 2, iter 660, avg. loss 97.54, avg. ppl 45.76 cum. examples 1920, speed 2915.41 words/sec, time elapsed 183.46 sec
# epoch 2, iter 670, avg. loss 94.16, avg. ppl 44.66 cum. examples 2240, speed 3538.18 words/sec, time elapsed 185.70 sec
# epoch 2, iter 680, avg. loss 101.52, avg. ppl 46.88 cum. examples 2560, speed 3309.34 words/sec, time elapsed 188.26 sec
# epoch 2, iter 690, avg. loss 103.41, avg. ppl 48.67 cum. examples 2880, speed 3407.30 words/sec, time elapsed 190.76 sec
# epoch 2, iter 700, avg. loss 99.95, avg. ppl 40.30 cum. examples 3200, speed 3190.40 words/sec, time elapsed 193.47 sec
# epoch 2, iter 710, avg. loss 98.28, avg. ppl 42.26 cum. examples 3520, speed 3464.36 words/sec, time elapsed 195.89 sec
# epoch 2, iter 720, avg. loss 101.23, avg. ppl 46.83 cum. examples 3840, speed 3111.15 words/sec, time elapsed 198.60 sec
# epoch 2, iter 730, avg. loss 101.36, avg. ppl 47.26 cum. examples 4160, speed 3398.84 words/sec, time elapsed 201.07 sec
# epoch 2, iter 740, avg. loss 100.66, avg. ppl 43.67 cum. examples 4480, speed 3484.69 words/sec, time elapsed 203.52 sec
# epoch 2, iter 750, avg. loss 92.94, avg. ppl 37.29 cum. examples 4800, speed 3507.63 words/sec, time elapsed 205.87 sec
# epoch 2, iter 760, avg. loss 96.13, avg. ppl 39.35 cum. examples 5120, speed 3457.95 words/sec, time elapsed 208.29 sec
# epoch 2, iter 770, avg. loss 96.89, avg. ppl 41.47 cum. examples 5440, speed 3214.59 words/sec, time elapsed 210.88 sec
# epoch 2, iter 780, avg. loss 94.83, avg. ppl 38.16 cum. examples 5760, speed 3363.99 words/sec, time elapsed 213.35 sec
# epoch 2, iter 790, avg. loss 95.19, avg. ppl 41.06 cum. examples 6080, speed 3309.04 words/sec, time elapsed 215.83 sec
# epoch 2, iter 800, avg. loss 94.53, avg. ppl 40.22 cum. examples 6400, speed 3461.53 words/sec, time elapsed 218.20 sec
# epoch 2, iter 800, cum. loss 98.84, cum. ppl 43.96 cum. examples 6400
# begin validation ...
# validation: iter 800, dev. ppl 55.626414
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 2, iter 810, avg. loss 99.98, avg. ppl 42.57 cum. examples 320, speed 1035.51 words/sec, time elapsed 226.43 sec
# epoch 2, iter 820, avg. loss 97.36, avg. ppl 38.87 cum. examples 640, speed 3575.23 words/sec, time elapsed 228.81 sec
# epoch 2, iter 830, avg. loss 93.85, avg. ppl 40.72 cum. examples 960, speed 3551.05 words/sec, time elapsed 231.10 sec
# epoch 2, iter 840, avg. loss 96.94, avg. ppl 39.00 cum. examples 1280, speed 3394.59 words/sec, time elapsed 233.59 sec
# epoch 2, iter 850, avg. loss 92.55, avg. ppl 37.12 cum. examples 1600, speed 3051.51 words/sec, time elapsed 236.28 sec
# epoch 2, iter 860, avg. loss 93.98, avg. ppl 39.06 cum. examples 1920, speed 3322.34 words/sec, time elapsed 238.75 sec
# epoch 2, iter 870, avg. loss 95.45, avg. ppl 39.56 cum. examples 2240, speed 3147.58 words/sec, time elapsed 241.38 sec
# epoch 2, iter 880, avg. loss 91.93, avg. ppl 37.46 cum. examples 2560, speed 3396.18 words/sec, time elapsed 243.78 sec
# epoch 2, iter 890, avg. loss 92.10, avg. ppl 36.91 cum. examples 2880, speed 3239.94 words/sec, time elapsed 246.30 sec
# epoch 2, iter 900, avg. loss 88.51, avg. ppl 33.75 cum. examples 3200, speed 3362.56 words/sec, time elapsed 248.69 sec
# epoch 2, iter 910, avg. loss 95.43, avg. ppl 38.16 cum. examples 3520, speed 2991.43 words/sec, time elapsed 251.49 sec
# epoch 2, iter 920, avg. loss 97.12, avg. ppl 38.49 cum. examples 3840, speed 3677.60 words/sec, time elapsed 253.81 sec
# epoch 2, iter 930, avg. loss 92.47, avg. ppl 34.07 cum. examples 4135, speed 3327.80 words/sec, time elapsed 256.13 sec
# epoch 3, iter 940, avg. loss 82.10, avg. ppl 23.91 cum. examples 4455, speed 3327.70 words/sec, time elapsed 258.62 sec
# epoch 3, iter 950, avg. loss 84.21, avg. ppl 24.46 cum. examples 4775, speed 3481.53 words/sec, time elapsed 261.04 sec
# epoch 3, iter 960, avg. loss 83.86, avg. ppl 23.34 cum. examples 5095, speed 3378.06 words/sec, time elapsed 263.56 sec
# epoch 3, iter 970, avg. loss 79.71, avg. ppl 23.88 cum. examples 5415, speed 3487.92 words/sec, time elapsed 265.87 sec
# epoch 3, iter 980, avg. loss 86.42, avg. ppl 22.58 cum. examples 5735, speed 3405.02 words/sec, time elapsed 268.47 sec
# epoch 3, iter 990, avg. loss 82.88, avg. ppl 23.04 cum. examples 6055, speed 3334.70 words/sec, time elapsed 271.01 sec
# epoch 3, iter 1000, avg. loss 81.91, avg. ppl 23.34 cum. examples 6375, speed 3690.29 words/sec, time elapsed 273.26 sec
# epoch 3, iter 1000, cum. loss 90.43, cum. ppl 32.10 cum. examples 6375
# begin validation ...
# validation: iter 1000, dev. ppl 48.938206
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 3, iter 1010, avg. loss 81.54, avg. ppl 20.93 cum. examples 320, speed 1034.85 words/sec, time elapsed 281.55 sec
# epoch 3, iter 1020, avg. loss 85.18, avg. ppl 25.20 cum. examples 640, speed 3011.00 words/sec, time elapsed 284.36 sec
# epoch 3, iter 1030, avg. loss 76.63, avg. ppl 20.60 cum. examples 960, speed 3302.04 words/sec, time elapsed 286.81 sec
# epoch 3, iter 1040, avg. loss 81.14, avg. ppl 23.94 cum. examples 1280, speed 3332.15 words/sec, time elapsed 289.27 sec
# epoch 3, iter 1050, avg. loss 84.39, avg. ppl 24.76 cum. examples 1600, speed 3126.48 words/sec, time elapsed 291.96 sec
# epoch 3, iter 1060, avg. loss 81.44, avg. ppl 23.17 cum. examples 1920, speed 3450.73 words/sec, time elapsed 294.36 sec
# epoch 3, iter 1070, avg. loss 83.28, avg. ppl 21.21 cum. examples 2240, speed 3391.18 words/sec, time elapsed 296.93 sec
# epoch 3, iter 1080, avg. loss 80.00, avg. ppl 21.68 cum. examples 2560, speed 3211.33 words/sec, time elapsed 299.52 sec
# epoch 3, iter 1090, avg. loss 75.82, avg. ppl 20.00 cum. examples 2880, speed 3509.05 words/sec, time elapsed 301.83 sec
# epoch 3, iter 1100, avg. loss 85.59, avg. ppl 23.95 cum. examples 3200, speed 3190.92 words/sec, time elapsed 304.53 sec
# epoch 3, iter 1110, avg. loss 83.28, avg. ppl 23.22 cum. examples 3520, speed 2621.91 words/sec, time elapsed 307.77 sec
# epoch 3, iter 1120, avg. loss 82.92, avg. ppl 24.60 cum. examples 3840, speed 3230.20 words/sec, time elapsed 310.33 sec
# epoch 3, iter 1130, avg. loss 74.35, avg. ppl 18.69 cum. examples 4160, speed 3212.22 words/sec, time elapsed 312.86 sec
# epoch 3, iter 1140, avg. loss 80.04, avg. ppl 21.78 cum. examples 4480, speed 3328.58 words/sec, time elapsed 315.36 sec
# epoch 3, iter 1150, avg. loss 84.45, avg. ppl 22.92 cum. examples 4800, speed 3398.22 words/sec, time elapsed 317.90 sec
# epoch 3, iter 1160, avg. loss 82.49, avg. ppl 21.37 cum. examples 5120, speed 3370.78 words/sec, time elapsed 320.45 sec
# epoch 3, iter 1170, avg. loss 77.16, avg. ppl 21.07 cum. examples 5440, speed 3327.67 words/sec, time elapsed 322.89 sec
# epoch 3, iter 1180, avg. loss 80.61, avg. ppl 21.66 cum. examples 5760, speed 3248.89 words/sec, time elapsed 325.47 sec
# epoch 3, iter 1190, avg. loss 80.16, avg. ppl 22.62 cum. examples 6080, speed 3517.05 words/sec, time elapsed 327.81 sec
# epoch 3, iter 1200, avg. loss 76.06, avg. ppl 20.54 cum. examples 6400, speed 3491.58 words/sec, time elapsed 330.12 sec
# epoch 3, iter 1200, cum. loss 80.83, cum. ppl 22.15 cum. examples 6400
# begin validation ...
# validation: iter 1200, dev. ppl 44.112956
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 3, iter 1210, avg. loss 75.94, avg. ppl 20.65 cum. examples 320, speed 950.45 words/sec, time elapsed 338.56 sec
# epoch 3, iter 1220, avg. loss 78.81, avg. ppl 21.14 cum. examples 640, speed 3616.79 words/sec, time elapsed 340.85 sec
# epoch 3, iter 1230, avg. loss 84.29, avg. ppl 23.58 cum. examples 960, speed 3340.93 words/sec, time elapsed 343.40 sec
# epoch 3, iter 1240, avg. loss 81.47, avg. ppl 22.42 cum. examples 1280, speed 3450.24 words/sec, time elapsed 345.83 sec
# epoch 3, iter 1250, avg. loss 78.79, avg. ppl 17.62 cum. examples 1600, speed 3544.03 words/sec, time elapsed 348.31 sec
# epoch 3, iter 1260, avg. loss 82.12, avg. ppl 21.98 cum. examples 1920, speed 3265.07 words/sec, time elapsed 350.92 sec
# epoch 3, iter 1270, avg. loss 85.88, avg. ppl 22.86 cum. examples 2240, speed 2868.59 words/sec, time elapsed 353.98 sec
# epoch 3, iter 1280, avg. loss 75.46, avg. ppl 18.76 cum. examples 2560, speed 3367.63 words/sec, time elapsed 356.42 sec
# epoch 3, iter 1290, avg. loss 75.94, avg. ppl 20.70 cum. examples 2880, speed 3444.70 words/sec, time elapsed 358.75 sec
# epoch 3, iter 1300, avg. loss 74.38, avg. ppl 20.58 cum. examples 3200, speed 3153.50 words/sec, time elapsed 361.25 sec
# epoch 3, iter 1310, avg. loss 84.91, avg. ppl 22.94 cum. examples 3520, speed 3311.01 words/sec, time elapsed 363.87 sec
# epoch 3, iter 1320, avg. loss 80.95, avg. ppl 22.13 cum. examples 3840, speed 3203.79 words/sec, time elapsed 366.48 sec
# epoch 3, iter 1330, avg. loss 77.34, avg. ppl 20.54 cum. examples 4160, speed 3436.28 words/sec, time elapsed 368.86 sec
# epoch 3, iter 1340, avg. loss 79.93, avg. ppl 21.55 cum. examples 4480, speed 3220.14 words/sec, time elapsed 371.45 sec
# epoch 3, iter 1350, avg. loss 78.77, avg. ppl 20.40 cum. examples 4800, speed 3106.41 words/sec, time elapsed 374.14 sec
# epoch 3, iter 1360, avg. loss 81.60, avg. ppl 21.81 cum. examples 5120, speed 3127.78 words/sec, time elapsed 376.85 sec
# epoch 3, iter 1370, avg. loss 72.44, avg. ppl 18.53 cum. examples 5440, speed 3550.33 words/sec, time elapsed 379.08 sec
# epoch 3, iter 1380, avg. loss 85.08, avg. ppl 23.29 cum. examples 5760, speed 2852.18 words/sec, time elapsed 382.12 sec
# epoch 3, iter 1390, avg. loss 79.95, avg. ppl 23.02 cum. examples 6080, speed 3440.80 words/sec, time elapsed 384.49 sec
# epoch 4, iter 1400, avg. loss 72.54, avg. ppl 14.66 cum. examples 6375, speed 3035.27 words/sec, time elapsed 387.11 sec
# epoch 4, iter 1400, cum. loss 79.36, cum. ppl 20.87 cum. examples 6375
# begin validation ...
# validation: iter 1400, dev. ppl 40.370108
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 4, iter 1410, avg. loss 61.68, avg. ppl 11.27 cum. examples 320, speed 972.90 words/sec, time elapsed 395.49 sec
# epoch 4, iter 1420, avg. loss 59.79, avg. ppl 10.19 cum. examples 640, speed 3380.58 words/sec, time elapsed 397.92 sec
# epoch 4, iter 1430, avg. loss 67.70, avg. ppl 12.65 cum. examples 960, speed 3091.95 words/sec, time elapsed 400.69 sec
# epoch 4, iter 1440, avg. loss 69.50, avg. ppl 12.72 cum. examples 1280, speed 3157.28 words/sec, time elapsed 403.46 sec
# epoch 4, iter 1450, avg. loss 64.80, avg. ppl 11.84 cum. examples 1600, speed 3191.49 words/sec, time elapsed 406.08 sec
# epoch 4, iter 1460, avg. loss 66.68, avg. ppl 14.34 cum. examples 1920, speed 3266.35 words/sec, time elapsed 408.54 sec
# epoch 4, iter 1470, avg. loss 66.89, avg. ppl 12.77 cum. examples 2240, speed 3442.79 words/sec, time elapsed 410.98 sec
# epoch 4, iter 1480, avg. loss 63.36, avg. ppl 11.77 cum. examples 2560, speed 3255.81 words/sec, time elapsed 413.50 sec
# epoch 4, iter 1490, avg. loss 63.83, avg. ppl 12.10 cum. examples 2880, speed 3347.03 words/sec, time elapsed 415.95 sec
# epoch 4, iter 1500, avg. loss 68.14, avg. ppl 12.90 cum. examples 3200, speed 2987.78 words/sec, time elapsed 418.81 sec
# epoch 4, iter 1510, avg. loss 61.85, avg. ppl 11.61 cum. examples 3520, speed 3290.50 words/sec, time elapsed 421.26 sec
# epoch 4, iter 1520, avg. loss 68.22, avg. ppl 13.27 cum. examples 3840, speed 3292.91 words/sec, time elapsed 423.82 sec
# epoch 4, iter 1530, avg. loss 64.43, avg. ppl 12.14 cum. examples 4160, speed 3206.34 words/sec, time elapsed 426.40 sec
# epoch 4, iter 1540, avg. loss 67.24, avg. ppl 13.55 cum. examples 4480, speed 3331.27 words/sec, time elapsed 428.88 sec
# epoch 4, iter 1550, avg. loss 69.74, avg. ppl 14.14 cum. examples 4800, speed 2769.02 words/sec, time elapsed 431.92 sec
# epoch 4, iter 1560, avg. loss 59.96, avg. ppl 10.94 cum. examples 5120, speed 3377.42 words/sec, time elapsed 434.30 sec
# epoch 4, iter 1570, avg. loss 65.10, avg. ppl 12.56 cum. examples 5440, speed 3489.92 words/sec, time elapsed 436.65 sec
# epoch 4, iter 1580, avg. loss 62.00, avg. ppl 12.15 cum. examples 5760, speed 3033.56 words/sec, time elapsed 439.27 sec
# epoch 4, iter 1590, avg. loss 65.47, avg. ppl 12.28 cum. examples 6080, speed 3280.39 words/sec, time elapsed 441.82 sec
# epoch 4, iter 1600, avg. loss 65.83, avg. ppl 12.07 cum. examples 6400, speed 3349.86 words/sec, time elapsed 444.34 sec
# epoch 4, iter 1600, cum. loss 65.11, cum. ppl 12.33 cum. examples 6400
# begin validation ...
# validation: iter 1600, dev. ppl 40.968022
# hit patience 1
# hit #1 trial
# load previously best model and decay learning rate to 0.000250
# restore parameters of the optimizers
# epoch 4, iter 1610, avg. loss 66.97, avg. ppl 12.77 cum. examples 320, speed 1366.12 words/sec, time elapsed 450.50 sec
# epoch 4, iter 1620, avg. loss 65.89, avg. ppl 11.64 cum. examples 640, speed 3534.27 words/sec, time elapsed 452.93 sec
# epoch 4, iter 1630, avg. loss 64.53, avg. ppl 12.26 cum. examples 960, speed 3253.71 words/sec, time elapsed 455.47 sec
# epoch 4, iter 1640, avg. loss 61.00, avg. ppl 10.90 cum. examples 1280, speed 3345.56 words/sec, time elapsed 457.91 sec
# epoch 4, iter 1650, avg. loss 63.89, avg. ppl 11.21 cum. examples 1600, speed 3258.32 words/sec, time elapsed 460.50 sec
# epoch 4, iter 1660, avg. loss 62.83, avg. ppl 10.79 cum. examples 1920, speed 3369.44 words/sec, time elapsed 463.01 sec
# epoch 4, iter 1670, avg. loss 63.37, avg. ppl 10.32 cum. examples 2240, speed 3456.53 words/sec, time elapsed 465.53 sec
# epoch 4, iter 1680, avg. loss 67.74, avg. ppl 11.82 cum. examples 2560, speed 3084.90 words/sec, time elapsed 468.37 sec
# epoch 4, iter 1690, avg. loss 61.75, avg. ppl 10.85 cum. examples 2880, speed 3384.05 words/sec, time elapsed 470.82 sec
# epoch 4, iter 1700, avg. loss 63.18, avg. ppl 11.65 cum. examples 3200, speed 3176.97 words/sec, time elapsed 473.41 sec
# epoch 4, iter 1710, avg. loss 63.67, avg. ppl 10.80 cum. examples 3520, speed 3576.40 words/sec, time elapsed 475.81 sec
# epoch 4, iter 1720, avg. loss 61.83, avg. ppl 10.91 cum. examples 3840, speed 3460.74 words/sec, time elapsed 478.20 sec
# epoch 4, iter 1730, avg. loss 62.04, avg. ppl 11.06 cum. examples 4160, speed 3175.63 words/sec, time elapsed 480.80 sec
# epoch 4, iter 1740, avg. loss 61.29, avg. ppl 10.35 cum. examples 4480, speed 3511.83 words/sec, time elapsed 483.19 sec
# epoch 4, iter 1750, avg. loss 59.41, avg. ppl 10.27 cum. examples 4800, speed 3364.64 words/sec, time elapsed 485.62 sec
# epoch 4, iter 1760, avg. loss 66.33, avg. ppl 12.61 cum. examples 5120, speed 3411.16 words/sec, time elapsed 488.07 sec
# epoch 4, iter 1770, avg. loss 61.90, avg. ppl 11.72 cum. examples 5440, speed 3382.44 words/sec, time elapsed 490.45 sec
# epoch 4, iter 1780, avg. loss 62.56, avg. ppl 10.57 cum. examples 5760, speed 3349.14 words/sec, time elapsed 492.99 sec
# epoch 4, iter 1790, avg. loss 63.54, avg. ppl 11.30 cum. examples 6080, speed 3159.51 words/sec, time elapsed 495.64 sec
# epoch 4, iter 1800, avg. loss 63.02, avg. ppl 10.86 cum. examples 6400, speed 3435.15 words/sec, time elapsed 498.10 sec
# epoch 4, iter 1800, cum. loss 63.34, cum. ppl 11.21 cum. examples 6400
# begin validation ...
# validation: iter 1800, dev. ppl 39.318015
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 4, iter 1810, avg. loss 59.93, avg. ppl 10.03 cum. examples 320, speed 950.35 words/sec, time elapsed 506.86 sec
# epoch 4, iter 1820, avg. loss 61.79, avg. ppl 10.90 cum. examples 640, speed 3266.61 words/sec, time elapsed 509.39 sec
# epoch 4, iter 1830, avg. loss 63.99, avg. ppl 10.85 cum. examples 960, speed 3397.17 words/sec, time elapsed 511.92 sec
# epoch 4, iter 1840, avg. loss 62.51, avg. ppl 10.88 cum. examples 1280, speed 3235.64 words/sec, time elapsed 514.51 sec
# epoch 4, iter 1850, avg. loss 64.05, avg. ppl 11.21 cum. examples 1600, speed 3219.03 words/sec, time elapsed 517.14 sec
# epoch 4, iter 1860, avg. loss 64.12, avg. ppl 11.11 cum. examples 1895, speed 3278.27 words/sec, time elapsed 519.54 sec
# epoch 5, iter 1870, avg. loss 59.01, avg. ppl 8.97 cum. examples 2215, speed 3376.92 words/sec, time elapsed 522.09 sec
# epoch 5, iter 1880, avg. loss 54.59, avg. ppl 8.06 cum. examples 2535, speed 3344.49 words/sec, time elapsed 524.59 sec
# epoch 5, iter 1890, avg. loss 55.58, avg. ppl 8.12 cum. examples 2855, speed 3262.68 words/sec, time elapsed 527.19 sec
# epoch 5, iter 1900, avg. loss 55.94, avg. ppl 8.28 cum. examples 3175, speed 3595.64 words/sec, time elapsed 529.55 sec
# epoch 5, iter 1910, avg. loss 53.16, avg. ppl 8.05 cum. examples 3495, speed 3367.69 words/sec, time elapsed 531.97 sec
# epoch 5, iter 1920, avg. loss 60.54, avg. ppl 9.57 cum. examples 3815, speed 3091.67 words/sec, time elapsed 534.74 sec
# epoch 5, iter 1930, avg. loss 51.65, avg. ppl 7.77 cum. examples 4135, speed 3561.19 words/sec, time elapsed 537.01 sec
# epoch 5, iter 1940, avg. loss 55.44, avg. ppl 8.41 cum. examples 4455, speed 2891.33 words/sec, time elapsed 539.89 sec
# epoch 5, iter 1950, avg. loss 57.98, avg. ppl 8.70 cum. examples 4775, speed 3562.94 words/sec, time elapsed 542.30 sec
# epoch 5, iter 1960, avg. loss 55.44, avg. ppl 8.44 cum. examples 5095, speed 3283.25 words/sec, time elapsed 544.83 sec
# epoch 5, iter 1970, avg. loss 58.53, avg. ppl 8.52 cum. examples 5415, speed 3668.49 words/sec, time elapsed 547.21 sec
# epoch 5, iter 1980, avg. loss 56.20, avg. ppl 8.94 cum. examples 5735, speed 3123.63 words/sec, time elapsed 549.84 sec
# epoch 5, iter 1990, avg. loss 59.67, avg. ppl 9.23 cum. examples 6055, speed 3153.23 words/sec, time elapsed 552.57 sec
# epoch 5, iter 2000, avg. loss 56.23, avg. ppl 8.72 cum. examples 6375, speed 3267.17 words/sec, time elapsed 555.11 sec
# epoch 5, iter 2000, cum. loss 58.30, cum. ppl 9.17 cum. examples 6375
# begin validation ...
# validation: iter 2000, dev. ppl 39.947705
# hit patience 1
# hit #2 trial
# load previously best model and decay learning rate to 0.000125
# restore parameters of the optimizers
# epoch 5, iter 2010, avg. loss 53.97, avg. ppl 8.75 cum. examples 320, speed 1385.85 words/sec, time elapsed 560.86 sec
# epoch 5, iter 2020, avg. loss 62.65, avg. ppl 10.96 cum. examples 640, speed 2786.18 words/sec, time elapsed 563.86 sec
# epoch 5, iter 2030, avg. loss 58.25, avg. ppl 9.62 cum. examples 960, speed 2872.05 words/sec, time elapsed 566.73 sec
# epoch 5, iter 2040, avg. loss 57.49, avg. ppl 9.25 cum. examples 1280, speed 3319.49 words/sec, time elapsed 569.22 sec
# epoch 5, iter 2050, avg. loss 54.18, avg. ppl 8.19 cum. examples 1600, speed 3516.61 words/sec, time elapsed 571.56 sec
# epoch 5, iter 2060, avg. loss 55.48, avg. ppl 8.60 cum. examples 1920, speed 3454.84 words/sec, time elapsed 573.95 sec
# epoch 5, iter 2070, avg. loss 53.83, avg. ppl 8.43 cum. examples 2240, speed 3275.91 words/sec, time elapsed 576.42 sec
# epoch 5, iter 2080, avg. loss 57.14, avg. ppl 8.97 cum. examples 2560, speed 3350.01 words/sec, time elapsed 578.91 sec
# epoch 5, iter 2090, avg. loss 57.48, avg. ppl 8.62 cum. examples 2880, speed 3451.93 words/sec, time elapsed 581.38 sec
# epoch 5, iter 2100, avg. loss 56.12, avg. ppl 8.58 cum. examples 3200, speed 3224.20 words/sec, time elapsed 583.97 sec
# epoch 5, iter 2110, avg. loss 57.17, avg. ppl 8.68 cum. examples 3520, speed 3412.52 words/sec, time elapsed 586.45 sec
# epoch 5, iter 2120, avg. loss 57.29, avg. ppl 9.48 cum. examples 3840, speed 3006.45 words/sec, time elapsed 589.16 sec
# epoch 5, iter 2130, avg. loss 56.61, avg. ppl 9.46 cum. examples 4160, speed 3254.89 words/sec, time elapsed 591.64 sec
# epoch 5, iter 2140, avg. loss 56.04, avg. ppl 9.13 cum. examples 4480, speed 2974.82 words/sec, time elapsed 594.37 sec
# epoch 5, iter 2150, avg. loss 54.94, avg. ppl 8.08 cum. examples 4800, speed 3472.45 words/sec, time elapsed 596.79 sec
# epoch 5, iter 2160, avg. loss 55.22, avg. ppl 8.38 cum. examples 5120, speed 3214.95 words/sec, time elapsed 599.38 sec
# epoch 5, iter 2170, avg. loss 61.27, avg. ppl 9.29 cum. examples 5440, speed 2430.15 words/sec, time elapsed 603.00 sec
# epoch 5, iter 2180, avg. loss 54.00, avg. ppl 7.68 cum. examples 5760, speed 3425.91 words/sec, time elapsed 605.47 sec
# epoch 5, iter 2190, avg. loss 55.96, avg. ppl 8.57 cum. examples 6080, speed 3197.47 words/sec, time elapsed 608.08 sec
# epoch 5, iter 2200, avg. loss 62.47, avg. ppl 9.79 cum. examples 6400, speed 3371.95 words/sec, time elapsed 610.68 sec
# epoch 5, iter 2200, cum. loss 56.88, cum. ppl 8.90 cum. examples 6400
# begin validation ...
# validation: iter 2200, dev. ppl 39.320083
# hit patience 1
# hit #3 trial
# load previously best model and decay learning rate to 0.000063
# restore parameters of the optimizers
# epoch 5, iter 2210, avg. loss 57.35, avg. ppl 9.34 cum. examples 320, speed 1397.45 words/sec, time elapsed 616.55 sec
# epoch 5, iter 2220, avg. loss 59.82, avg. ppl 9.75 cum. examples 640, speed 3358.24 words/sec, time elapsed 619.06 sec
# epoch 5, iter 2230, avg. loss 53.85, avg. ppl 8.23 cum. examples 960, speed 3342.89 words/sec, time elapsed 621.50 sec
# epoch 5, iter 2240, avg. loss 55.69, avg. ppl 8.49 cum. examples 1280, speed 3666.48 words/sec, time elapsed 623.78 sec
# epoch 5, iter 2250, avg. loss 57.71, avg. ppl 8.88 cum. examples 1600, speed 3405.55 words/sec, time elapsed 626.26 sec
# epoch 5, iter 2260, avg. loss 55.98, avg. ppl 9.07 cum. examples 1920, speed 3234.70 words/sec, time elapsed 628.77 sec
# epoch 5, iter 2270, avg. loss 58.30, avg. ppl 8.92 cum. examples 2240, speed 3364.81 words/sec, time elapsed 631.30 sec
# epoch 5, iter 2280, avg. loss 59.25, avg. ppl 8.90 cum. examples 2560, speed 3483.34 words/sec, time elapsed 633.80 sec
# epoch 5, iter 2290, avg. loss 57.19, avg. ppl 8.48 cum. examples 2880, speed 3439.79 words/sec, time elapsed 636.28 sec
# epoch 5, iter 2300, avg. loss 58.25, avg. ppl 9.11 cum. examples 3200, speed 3315.91 words/sec, time elapsed 638.83 sec
# epoch 5, iter 2310, avg. loss 55.82, avg. ppl 8.65 cum. examples 3520, speed 3362.83 words/sec, time elapsed 641.29 sec
# epoch 5, iter 2320, avg. loss 53.14, avg. ppl 8.26 cum. examples 3840, speed 3370.82 words/sec, time elapsed 643.68 sec
# epoch 6, iter 2330, avg. loss 53.72, avg. ppl 8.54 cum. examples 4135, speed 3237.40 words/sec, time elapsed 645.96 sec
# epoch 6, iter 2340, avg. loss 53.93, avg. ppl 8.37 cum. examples 4455, speed 3336.31 words/sec, time elapsed 648.40 sec
# epoch 6, iter 2350, avg. loss 58.27, avg. ppl 8.70 cum. examples 4775, speed 3177.78 words/sec, time elapsed 651.11 sec
# epoch 6, iter 2360, avg. loss 55.60, avg. ppl 8.59 cum. examples 5095, speed 3020.81 words/sec, time elapsed 653.85 sec
# epoch 6, iter 2370, avg. loss 51.45, avg. ppl 8.08 cum. examples 5415, speed 3487.70 words/sec, time elapsed 656.11 sec
# epoch 6, iter 2380, avg. loss 50.46, avg. ppl 7.43 cum. examples 5735, speed 3566.08 words/sec, time elapsed 658.37 sec
# epoch 6, iter 2390, avg. loss 51.73, avg. ppl 7.79 cum. examples 6055, speed 3201.20 words/sec, time elapsed 660.89 sec
# epoch 6, iter 2400, avg. loss 56.77, avg. ppl 8.13 cum. examples 6375, speed 3337.61 words/sec, time elapsed 663.48 sec
# epoch 6, iter 2400, cum. loss 55.72, cum. ppl 8.57 cum. examples 6375
# begin validation ...
# validation: iter 2400, dev. ppl 39.207935
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 6, iter 2410, avg. loss 56.01, avg. ppl 7.87 cum. examples 320, speed 1029.68 words/sec, time elapsed 671.92 sec
# epoch 6, iter 2420, avg. loss 53.56, avg. ppl 7.99 cum. examples 640, speed 3288.15 words/sec, time elapsed 674.43 sec
# epoch 6, iter 2430, avg. loss 55.81, avg. ppl 8.34 cum. examples 960, speed 3481.13 words/sec, time elapsed 676.85 sec
# epoch 6, iter 2440, avg. loss 56.21, avg. ppl 8.51 cum. examples 1280, speed 3573.14 words/sec, time elapsed 679.20 sec
# epoch 6, iter 2450, avg. loss 56.33, avg. ppl 8.25 cum. examples 1600, speed 3160.66 words/sec, time elapsed 681.91 sec
# epoch 6, iter 2460, avg. loss 54.65, avg. ppl 7.77 cum. examples 1920, speed 3471.20 words/sec, time elapsed 684.36 sec
# epoch 6, iter 2470, avg. loss 55.74, avg. ppl 8.11 cum. examples 2240, speed 3706.49 words/sec, time elapsed 686.66 sec
# epoch 6, iter 2480, avg. loss 52.70, avg. ppl 7.88 cum. examples 2560, speed 3486.89 words/sec, time elapsed 689.00 sec
# epoch 6, iter 2490, avg. loss 58.06, avg. ppl 8.91 cum. examples 2880, speed 3242.20 words/sec, time elapsed 691.62 sec
# epoch 6, iter 2500, avg. loss 62.18, avg. ppl 8.62 cum. examples 3200, speed 3289.48 words/sec, time elapsed 694.43 sec
# epoch 6, iter 2510, avg. loss 55.49, avg. ppl 8.33 cum. examples 3520, speed 3383.03 words/sec, time elapsed 696.91 sec
# epoch 6, iter 2520, avg. loss 52.62, avg. ppl 7.57 cum. examples 3840, speed 3386.93 words/sec, time elapsed 699.37 sec
# epoch 6, iter 2530, avg. loss 57.70, avg. ppl 8.68 cum. examples 4160, speed 3022.84 words/sec, time elapsed 702.19 sec
# epoch 6, iter 2540, avg. loss 57.34, avg. ppl 8.19 cum. examples 4480, speed 3352.32 words/sec, time elapsed 704.80 sec
# epoch 6, iter 2550, avg. loss 57.09, avg. ppl 8.92 cum. examples 4800, speed 3126.38 words/sec, time elapsed 707.47 sec
# epoch 6, iter 2560, avg. loss 49.82, avg. ppl 7.56 cum. examples 5120, speed 3103.50 words/sec, time elapsed 710.01 sec
# epoch 6, iter 2570, avg. loss 60.41, avg. ppl 9.17 cum. examples 5440, speed 3112.08 words/sec, time elapsed 712.81 sec
# epoch 6, iter 2580, avg. loss 57.56, avg. ppl 8.68 cum. examples 5760, speed 2837.71 words/sec, time elapsed 715.81 sec
# epoch 6, iter 2590, avg. loss 57.10, avg. ppl 9.06 cum. examples 6080, speed 3305.20 words/sec, time elapsed 718.32 sec
# epoch 6, iter 2600, avg. loss 59.26, avg. ppl 8.72 cum. examples 6400, speed 3085.25 words/sec, time elapsed 721.16 sec
# epoch 6, iter 2600, cum. loss 56.28, cum. ppl 8.35 cum. examples 6400
# begin validation ...
# validation: iter 2600, dev. ppl 39.073178
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 6, iter 2610, avg. loss 54.63, avg. ppl 7.90 cum. examples 320, speed 960.67 words/sec, time elapsed 729.96 sec
# epoch 6, iter 2620, avg. loss 53.93, avg. ppl 8.49 cum. examples 640, speed 3526.73 words/sec, time elapsed 732.25 sec
# epoch 6, iter 2630, avg. loss 53.05, avg. ppl 8.03 cum. examples 960, speed 3282.70 words/sec, time elapsed 734.73 sec
# epoch 6, iter 2640, avg. loss 52.21, avg. ppl 8.01 cum. examples 1280, speed 3258.80 words/sec, time elapsed 737.20 sec
# epoch 6, iter 2650, avg. loss 56.64, avg. ppl 8.23 cum. examples 1600, speed 3345.60 words/sec, time elapsed 739.77 sec
# epoch 6, iter 2660, avg. loss 52.12, avg. ppl 7.69 cum. examples 1920, speed 3348.99 words/sec, time elapsed 742.21 sec
# epoch 6, iter 2670, avg. loss 53.50, avg. ppl 7.60 cum. examples 2240, speed 3532.73 words/sec, time elapsed 744.60 sec
# epoch 6, iter 2680, avg. loss 52.75, avg. ppl 8.03 cum. examples 2560, speed 3203.19 words/sec, time elapsed 747.13 sec
# epoch 6, iter 2690, avg. loss 55.17, avg. ppl 8.63 cum. examples 2880, speed 3140.67 words/sec, time elapsed 749.74 sec
# epoch 6, iter 2700, avg. loss 50.57, avg. ppl 7.63 cum. examples 3200, speed 3406.27 words/sec, time elapsed 752.07 sec
# epoch 6, iter 2710, avg. loss 52.00, avg. ppl 7.45 cum. examples 3520, speed 3237.94 words/sec, time elapsed 754.63 sec
# epoch 6, iter 2720, avg. loss 50.84, avg. ppl 7.97 cum. examples 3840, speed 3131.92 words/sec, time elapsed 757.14 sec
# epoch 6, iter 2730, avg. loss 53.12, avg. ppl 7.91 cum. examples 4160, speed 3307.21 words/sec, time elapsed 759.62 sec
# epoch 6, iter 2740, avg. loss 54.68, avg. ppl 8.34 cum. examples 4480, speed 3375.09 words/sec, time elapsed 762.07 sec
# epoch 6, iter 2750, avg. loss 57.62, avg. ppl 8.75 cum. examples 4800, speed 2937.87 words/sec, time elapsed 764.96 sec
# epoch 6, iter 2760, avg. loss 53.09, avg. ppl 8.08 cum. examples 5120, speed 3498.93 words/sec, time elapsed 767.28 sec
# epoch 6, iter 2770, avg. loss 57.50, avg. ppl 8.43 cum. examples 5440, speed 3413.16 words/sec, time elapsed 769.81 sec
# epoch 6, iter 2780, avg. loss 56.14, avg. ppl 8.10 cum. examples 5760, speed 2974.30 words/sec, time elapsed 772.70 sec
# epoch 6, iter 2790, avg. loss 55.34, avg. ppl 7.92 cum. examples 6055, speed 3186.35 words/sec, time elapsed 775.18 sec
# epoch 7, iter 2800, avg. loss 50.54, avg. ppl 6.95 cum. examples 6375, speed 3282.71 words/sec, time elapsed 777.72 sec
# epoch 7, iter 2800, cum. loss 53.77, cum. ppl 8.00 cum. examples 6375
# begin validation ...
# validation: iter 2800, dev. ppl 39.544978
# hit patience 1
# hit #4 trial
# load previously best model and decay learning rate to 0.000031
# restore parameters of the optimizers
# epoch 7, iter 2810, avg. loss 48.30, avg. ppl 6.91 cum. examples 320, speed 1300.58 words/sec, time elapsed 783.87 sec
# epoch 7, iter 2820, avg. loss 52.98, avg. ppl 7.11 cum. examples 640, speed 3441.87 words/sec, time elapsed 786.38 sec
# epoch 7, iter 2830, avg. loss 53.47, avg. ppl 7.87 cum. examples 960, speed 3467.75 words/sec, time elapsed 788.77 sec
# epoch 7, iter 2840, avg. loss 52.23, avg. ppl 7.20 cum. examples 1280, speed 3175.72 words/sec, time elapsed 791.43 sec
# epoch 7, iter 2850, avg. loss 51.59, avg. ppl 7.10 cum. examples 1600, speed 3492.20 words/sec, time elapsed 793.85 sec
# epoch 7, iter 2860, avg. loss 54.13, avg. ppl 7.88 cum. examples 1920, speed 3427.48 words/sec, time elapsed 796.30 sec
# epoch 7, iter 2870, avg. loss 53.51, avg. ppl 7.80 cum. examples 2240, speed 3412.79 words/sec, time elapsed 798.74 sec
# epoch 7, iter 2880, avg. loss 51.92, avg. ppl 7.51 cum. examples 2560, speed 3295.93 words/sec, time elapsed 801.24 sec
# epoch 7, iter 2890, avg. loss 56.94, avg. ppl 8.35 cum. examples 2880, speed 3155.69 words/sec, time elapsed 803.96 sec
# epoch 7, iter 2900, avg. loss 51.85, avg. ppl 7.47 cum. examples 3200, speed 3157.62 words/sec, time elapsed 806.57 sec
# epoch 7, iter 2910, avg. loss 53.60, avg. ppl 7.55 cum. examples 3520, speed 3351.63 words/sec, time elapsed 809.10 sec
# epoch 7, iter 2920, avg. loss 52.84, avg. ppl 7.51 cum. examples 3840, speed 3051.97 words/sec, time elapsed 811.85 sec
# epoch 7, iter 2930, avg. loss 55.98, avg. ppl 8.19 cum. examples 4160, speed 3545.91 words/sec, time elapsed 814.25 sec
# epoch 7, iter 2940, avg. loss 50.85, avg. ppl 7.10 cum. examples 4480, speed 3331.09 words/sec, time elapsed 816.75 sec
# epoch 7, iter 2950, avg. loss 51.63, avg. ppl 7.20 cum. examples 4800, speed 3421.71 words/sec, time elapsed 819.19 sec
# epoch 7, iter 2960, avg. loss 52.96, avg. ppl 7.38 cum. examples 5120, speed 3422.52 words/sec, time elapsed 821.67 sec
# epoch 7, iter 2970, avg. loss 53.86, avg. ppl 7.72 cum. examples 5440, speed 3573.54 words/sec, time elapsed 824.03 sec
# epoch 7, iter 2980, avg. loss 54.75, avg. ppl 7.90 cum. examples 5760, speed 2856.11 words/sec, time elapsed 827.00 sec
# epoch 7, iter 2990, avg. loss 53.68, avg. ppl 7.38 cum. examples 6080, speed 3301.08 words/sec, time elapsed 829.60 sec
# epoch 7, iter 3000, avg. loss 49.78, avg. ppl 7.38 cum. examples 6400, speed 3332.22 words/sec, time elapsed 831.99 sec
# epoch 7, iter 3000, cum. loss 52.84, cum. ppl 7.52 cum. examples 6400
# begin validation ...
# validation: iter 3000, dev. ppl 39.918790
# hit patience 1
# hit #5 trial
# early stop!

# %%
# %%shell
# sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./chr_en_data/test.chr]
# load test target sentences from [./chr_en_data/test.en]
# load model from model.bin
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Decoding:   0% 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Decoding: 100% 1000/1000 [00:50<00:00, 19.76it/s]
# Corpus BLEU: 12.570136256849953
